# %% [markdown]
# # **Predict_Random_Pics_Using_ResNet50_CNN_Model**

# %% [markdown]
# ## **1-Import Libraries**

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from os import listdir
from PIL import Image as PImage
from keras.preprocessing import image

# %% [markdown]
# ## **2-Load RESNET50 CNN Model**

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import decode_predictions

# %% [markdown]
# ## **3-Setup Image Width & Height**

# %%
img_width, img_height = 224, 224

# %% [markdown]
# ## **4-Load Pretrained Model**

# %%
model_pretrained = ResNet50(weights='imagenet', 
                      include_top=True, 
                      input_shape=(img_height, img_width, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 1s 0us/step
# 102981632/102967424 [==============================] - 1s 0us/step

# %% [markdown]
# ## **5-Load Dataset from Google Drive**

# %%
import zipfile

# unzip the downloaded file
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/sample_pics.zip")
zip_ref.extractall()
zip_ref.close()

# %% [markdown]
# ## **6-Insert Correct Path of Image**

# %%
# Insert correct path of your image below
img_path = '/content/_-txX-7CCCk.jpg'
img = image.load_img(img_path, target_size=(img_width, img_height))
img_data = image.img_to_array(img)
img_data = np.expand_dims(img_data, axis=0)
img_data = tf.keras.applications.resnet50.preprocess_input(img_data)

# %% [markdown]
# ## **7-Predict The Results**

# %%
cnn_feature = model_pretrained.predict(img_data,verbose=0)
# decode the results into a list of tuples (class, description, probability)
label = decode_predictions(cnn_feature)
label = label[0][0]
 
 
plt.imshow(img)
 
stringprint ="%.1f" % round(label[2]*100,1)
plt.title(label[1] + " " + str(stringprint) + "%", fontsize=20)
plt.axis('off')
plt.show()

# %% [markdown]
# ## **8-Predict Some Other Pictures**

# %%
# Insert correct path of your image below
img_path = '/content/OO4gobHWfTM.jpg'
img = image.load_img(img_path, target_size=(img_width, img_height))
img_data = image.img_to_array(img)
img_data = np.expand_dims(img_data, axis=0)
img_data = tf.keras.applications.resnet50.preprocess_input(img_data)

# %%
cnn_feature = model_pretrained.predict(img_data,verbose=0)
# decode the results into a list of tuples (class, description, probability)
label = decode_predictions(cnn_feature)
label = label[0][0]
 
 
plt.imshow(img)
 
stringprint ="%.1f" % round(label[2]*100,1)
plt.title(label[1] + " " + str(stringprint) + "%", fontsize=20)
plt.axis('off')
plt.show()

# %%
# Insert correct path of your image below
img_path = '/content/TsicpD7pcHw.jpg'
img = image.load_img(img_path, target_size=(img_width, img_height))
img_data = image.img_to_array(img)
img_data = np.expand_dims(img_data, axis=0)
img_data = tf.keras.applications.resnet50.preprocess_input(img_data)

# %%
cnn_feature = model_pretrained.predict(img_data,verbose=0)
# decode the results into a list of tuples (class, description, probability)
label = decode_predictions(cnn_feature)
label = label[0][0]
 
 
plt.imshow(img)
 
stringprint ="%.1f" % round(label[2]*100,1)
plt.title(label[1] + " " + str(stringprint) + "%", fontsize=20)
plt.axis('off')
plt.show()
